# %%
import numpy as np
import scipy as sp
# testing numpy integrate stuff
 # NOTE(BOB) solution = sp.integrate.solve_ivp( function? , array?   self.dx? 
def f(t, y0):
    x, y = y0
    fx = 1
    fy = t
    return fx, fy


bobsol = sp.integrate.solve_ivp(f, (-5,5), (0,0), t_eval=np.linspace(-5,5,21))
x, y = bobsol.y
print(x)
print(y)
print(bobsol.t)
import matplotlib.pyplot as plt
plt.plot(x,y)
plt.axis("scaled")
plt.show()
# Out:
# [ 0.   0.5  1.   1.5  2.   2.5  3.   3.5  4.   4.5  5.   5.5  6.   6.5
#   7.   7.5  8.   8.5  9.   9.5 10. ]
# [ 0.0000000e+00 -2.3750000e+00 -4.5000000e+00 -6.3750000e+00
#  -8.0000000e+00 -9.3750000e+00 -1.0500000e+01 -1.1375000e+01
#  -1.2000000e+01 -1.2375000e+01 -1.2500000e+01 -1.2375000e+01
#  -1.2000000e+01 -1.1375000e+01 -1.0500000e+01 -9.3750000e+00
#  -8.0000000e+00 -6.3750000e+00 -4.5000000e+00 -2.3750000e+00
#  -4.4408921e-15]
# [-5.  -4.5 -4.  -3.5 -3.  -2.5 -2.  -1.5 -1.  -0.5  0.   0.5  1.   1.5
#   2.   2.5  3.   3.5  4.   4.5  5. ]
